# %%
import matplotlib.pyplot as plt
import numpy as np
import circle_fit as cf
import os
import cv2
# %run Functions.ipynb

# %% [markdown]
# ## 重複過半的 Pixel 才拿來用

# %%
def Get_ROI_Loc(cy,cx,cr):
    ## Loc 從左上到右下，y放前面（符合 image 讀取）
    x, y, r = int(round(cx)), int(round(cy)), int(round(cr))
    roi_loc = [[x-r-10, y-r-10], [x+r+10, y+r+10] ]
    return np.asarray(roi_loc)

# %%
def Get_ROI(image):
    ## 拿一張影像先算 Center 拿來取 ROI
    _, _, _, edge = image_processing(image)
    edge_pts = get_edge_points(edge)
    cx,cy,cr,_ = cf.least_squares_circle((edge_pts))
    
    roi_loc = Get_ROI_Loc(cy,cx,cr)
    return roi_loc

# %%
def Analize_Multi_Frames(roi_loc, images):
    ## 取得所有當批影像的 ROI 
    lx, ly = roi_loc[0,:]
    rx, ry = roi_loc[1,:]
    imgs_crop = [image[ly:ry, lx:rx] for image in images]
    
    
    ## 取得每張邊緣影像的
    imgs_edge = []
    for cropped in imgs_crop:
        _, _, _, edge = image_processing(cropped)
        imgs_edge.append(edge)
    
    
    ## 取得每張邊緣的點
    imgs_edge_pts = [get_edge_points(edge) for edge in imgs_edge]
    
    
    ## 產生 Map 來紀錄出現次數
    Map = np.zeros(images[0].shape)
    for img_edge_pts in imgs_edge_pts:
        for x, y in img_edge_pts:
            Map[y,x] = Map[y,x] + 1
   
    
    # 塞選出重複出現一半次數的點
    valid_pts = []
    for i, row in enumerate(Map):
        for j, val in enumerate(row):
            if(val >= 5):
                valid_pts.append([j,i])
    
    cx, cy, r, _ = cf.least_squares_circle((valid_pts))
    predicted = [cx+lx, cy+ly] 
    return predicted

# %% [markdown]
# ## 測試前檢查

# %%
os.chdir("/home/mj/Github/NTU/ARCS/img/X-Ray/New/Case_1")
files = os.listdir()
files.sort()
files = np.asarray(files)
batches = np.split(files, 297)

img = cv2.imread(files[0], 0)
roi_loc = Get_ROI(img)

lx, ly = roi_loc[0,:]
rx, ry = roi_loc[1,:]
imgs_crop = img[ly:ry, lx:rx]

blur, nlm, otsu, edge = image_processing(imgs_crop)

cv2.imshow("Blur", blur)
cv2.imshow("Nlm", nlm)
cv2.imshow("Otsu", otsu)
cv2.imshow("Edge", edge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 尋找可能 Pattern

# %%
folder_path = "/home/mj/Github/NTU/ARCS/img/X-Ray/New/Case_2"
file_name = "Case_2969.bmp"
Map_path = "/home/mj/Github/NTU/ARCS/Demo/2020.01.14"
Map_name = "Case2_Map.bmp"

img = cv2.imread("{}/{}".format(folder_path, file_name), 0)
Map = cv2.imread("{}/{}".format(Map_path, Map_name))
h,w = img.shape[:2]

_, nlm, _, edge = image_processing(img)
edge_points = get_edge_points(edge)


## 分析點在 NLM 上值的分佈
vals = []
for x, y in edge_points:
    vals.append(nlm[y,x])

print("Mean", np.mean(vals))
print("Var", np.var(vals))
print("Min", min(vals))
print("Max", max(vals))

plt.hist(vals)
plt.show()

##  獲得比較表
for x, y in edge_points:
    if (np.array_equal(Map[y,x,:], [0,0,255])):
        Map[y,x,:] = [88,113,254]
    elif (np.array_equal(Map[y,x,:], [0,118,238])):
        Map[y,x,:] = [88,113,114]
    else:
        Map[y,x,:] = [255,255,255]
        
cx,cy,cr,_ = cf.least_squares_circle((edge_points))
print("Cx = {}\nCy = {}\nCr = {}".format(cx,cy,cr))
cv2.imshow("Comapred", Map)
cv2.imshow("NLM", nlm)

while(True):
    if (cv2.waitKey(10) & 0xff == ord('q')):
        break
cv2.destroyAllWindows()
# Out:
# Mean 154.52887537993922
# Var 0.35250967747895895
# Min 153
# Max 156
# Cx = 85.44592442195275
# Cy = 63.78149293972794
# Cr = 50.656967715586575

# %%
# Out:
# [152, 153, 154, 151]

# %%
folder_path = "/home/mj/HardDisk/Github/NTU/ARCS/img/X-Ray/New/Case_3"

files = os.listdir(folder_path)
files.sort()
for file in files:
    img = cv2.imread("{}/{}".format(folder_path, file), 0)
    _, nlm, _, edge = image_processing(img)
    edge_points = get_edge_points(edge)


    ## 分析點在 NLM 上值的分佈
    vals = []
    for x, y in edge_points:
        vals.append(nlm[y,x])

    print("Mean", np.mean(vals))
    print("Min", min(vals))
    print("Max", max(vals))
    plt.hist(vals)
    plt.show()
# Out:
# Mean 143.2189349112426
# Min 139
# Max 147
# Mean 143.36498516320475
# Min 140
# Max 148
# Mean 143.53982300884957
# Min 139
# Max 147
# Mean 143.35882352941175
# Min 140
# Max 147
# Mean 145.43026706231453
# Min 140
# Max 150
# Mean 145.39233038348084
# Min 141
# Max 149
# Mean 144.45697329376856
# Min 140
# Max 148
# Mean 144.44542772861357
# Min 141
# Max 149
# Mean 144.4513274336283
# Min 141
# Max 149
# Mean 145.40059347181008
# Min 142
# Max 150
# Mean 145.38823529411764
# Min 141
# Max 150
# Mean 145.4378698224852
# Min 141
# Max 150
# Mean 145.41964285714286
# Min 141
# Max 149
# Mean 144.47619047619048
# Min 141
# Max 148
# Mean 143.46153846153845
# Min 140
# Max 147
# Mean 144.43543543543544
# Min 141
# Max 148
# Mean 145.38575667655786
# Min 141
# Max 150
# Mean 145.47462686567164
# Min 141
# Max 149
# Mean 145.47916666666666
# Min 141
# Max 150
# Mean 145.48511904761904
# Min 140
# Max 150
# Mean 145.51940298507463
# Min 140
# Max 150
# Mean 145.4672619047619
# Min 141
# Max 150
# Mean 145.54626865671642
# Min 141
# Max 150
# Mean 145.4029411764706
# Min 142
# Max 150
# Mean 145.38529411764705
# Min 141
# Max 149
# Mean 143.43362831858408
# Min 140
# Max 147
# Mean 145.47633136094674
# Min 141
# Max 149
# Mean 145.46567164179103
# Min 142
# Max 149
# Mean 145.41246290801186
# Min 141
# Max 150
# Mean 145.52083333333334
# Min 142
# Max 150
# Mean 145.47904191616766
# Min 141
# Max 150
# Mean 145.39880952380952
# Min 141
# Max 149
# Mean 144.42388059701491
# Min 141
# Max 149
# Mean 144.52552552552552
# Min 140
# Max 148
# Mean 144.44213649851633
# Min 140
# Max 148
# Mean 145.56637168141592
# Min 141
# Max 150
# Mean 144.49262536873155
# Min 140
# Max 149
# Mean 145.55917159763314
# Min 141
# Max 150
# Mean 145.4925816023739
# Min 141
# Max 149
# Mean 145.49554896142433
# Min 142
# Max 150
# Mean 144.43491124260356
# Min 141
# Max 149
# Mean 145.46017699115043
# Min 141
# Max 150
# Mean 145.55786350148367
# Min 141
# Max 150
# Mean 145.5192878338279
# Min 141
# Max 149
# Mean 145.56973293768547
# Min 141
# Max 150
# Mean 145.52083333333334
# Min 142
# Max 150
# Mean 144.46745562130178
# Min 140
# Max 148
# Mean 144.48235294117646
# Min 140
# Max 149
# Mean 144.32544378698225
# Min 140
# Max 148
# Mean 145.34017595307918
# Min 141
# Max 149
# Mean 145.38278931750742
# Min 141
# Max 149
# Mean 145.3470588235294
# Min 141
# Max 149
# Mean 145.2797619047619
# Min 141
# Max 149
# Mean 144.48816568047337
# Min 141
# Max 149
# Mean 144.44179104477612
# Min 140
# Max 149
# Mean 145.58579881656806
# Min 142
# Max 150
# Mean 145.37573964497042
# Min 141
# Max 150
# Mean 145.3946587537092
# Min 142
# Max 150
# Mean 143.51940298507463
# Min 140
# Max 148
# Mean 144.4306784660767
# Min 141
# Max 148
# Mean 144.39285714285714
# Min 140
# Max 148
# Mean 144.41964285714286
# Min 140
# Max 149
# Mean 145.55621301775147
# Min 142
# Max 150
# Mean 145.42899408284023
# Min 142
# Max 150
# Mean 145.3716814159292
# Min 142
# Max 150
# Mean 144.38529411764705
# Min 141
# Max 148
# Mean 144.43401759530792
# Min 141
# Max 148
# Mean 144.47492625368733
# Min 141
# Max 149
# Mean 145.44378698224853
# Min 141
# Max 150
# Mean 143.52380952380952
# Min 139
# Max 148
# Mean 145.3491124260355
# Min 141
# Max 150
# Mean 145.2735294117647
# Min 141
# Max 149
# Mean 145.3952802359882
# Min 141
# Max 150
# Mean 145.43952802359883
# Min 141
# Max 149
# Mean 145.51641791044776
# Min 142
# Max 150
# Mean 145.36578171091446
# Min 142
# Max 150
# Mean 145.42985074626867
# Min 142
# Max 150
# Mean 145.39940828402368
# Min 142
# Max 150
# Mean 145.43154761904762
# Min 141
# Max 150
# Mean 144.43529411764706
# Min 140
# Max 148
# Mean 143.4213649851632
# Min 140
# Max 147
# Mean 145.35714285714286
# Min 141
# Max 149
# Mean 145.38622754491018
# Min 141
# Max 150
# Mean 145.46407185628743
# Min 141
# Max 150
# Mean 145.3491124260355
# Min 140
# Max 150
# Mean 145.39117647058825
# Min 141
# Max 150
# Mean 145.3343195266272
# Min 141
# Max 149
# Mean 145.39583333333334
# Min 141
# Max 150
# Mean 145.43026706231453
# Min 142
# Max 150
# Mean 145.4896755162242
# Min 142
# Max 150
# Mean 145.48082595870207
# Min 141
# Max 150
# Mean 143.43235294117648
# Min 140
# Max 147
# Mean 144.39940828402368
# Min 141
# Max 149
# Mean 145.43026706231453
# Min 141
# Max 150
# Mean 145.4467455621302
# Min 141
# Max 150
# Mean 145.45857988165682
# Min 141
# Max 150
# Mean 145.3313432835821
# Min 141
# Max 150
# Mean 145.35905044510386
# Min 141
# Max 149
# Mean 145.41071428571428
# Min 141
# Max 150
# Mean 145.40059347181008
# Min 142
# Max 149
# Mean 145.4378698224852
# Min 142
# Max 149
# Mean 145.39940828402368
# Min 141
# Max 149
# Mean 143.3846153846154
# Min 140
# Max 148
# Mean 145.54277286135692
# Min 141
# Max 149
# Mean 145.50746268656715
# Min 141
# Max 149
# Mean 145.4702380952381
# Min 141
# Max 149
# Mean 144.35798816568047
# Min 140
# Max 148
# Mean 145.34310850439883
# Min 141
# Max 150
# Mean 145.39880952380952
# Min 142
# Max 149
# Mean 145.43620178041542
# Min 141
# Max 149
# Mean 145.41246290801186
# Min 142
# Max 149
# Mean 144.5207100591716
# Min 140
# Max 148
# Mean 144.3598820058997
# Min 140
# Max 148
# Mean 143.55917159763314
# Min 140
# Max 147
# Mean 143.4940828402367
# Min 140
# Max 147
# Mean 145.42352941176472
# Min 141
# Max 150
# Mean 145.49411764705883
# Min 141
# Max 149
# Mean 145.4658753709199
# Min 142
# Max 149
# Mean 145.51038575667656
# Min 142
# Max 150
# Mean 145.4702380952381
# Min 142
# Max 149
# Mean 145.41964285714286
# Min 141
# Max 149
# Mean 145.45535714285714
# Min 141
# Max 149
# Mean 145.5625
# Min 142
# Max 150
# Mean 145.51190476190476
# Min 142
# Max 150
# Mean 144.53869047619048
# Min 141
# Max 149
# Mean 143.45562130177515
# Min 140
# Max 147
# Mean 144.5192878338279
# Min 141
# Max 149
# Mean 144.44082840236686
# Min 141
# Max 148
# Mean 145.2890855457227
# Min 140
# Max 150
# Mean 145.27777777777777
# Min 141
# Max 149
# Mean 145.33235294117648
# Min 141
# Max 150
# Mean 145.41764705882352
# Min 141
# Max 150
# Mean 145.39411764705883
# Min 141
# Max 149
# Mean 145.47619047619048
# Min 142
# Max 150
# Mean 145.41194029850746
# Min 142
# Max 149
# Mean 145.43952802359883
# Min 142
# Max 150
# Mean 143.40828402366864
# Min 140
# Max 148
# Mean 145.4540059347181
# Min 142
# Max 150
# Mean 145.46428571428572
# Min 142
# Max 150
# Mean 145.513353115727
# Min 141
# Max 149
# Mean 145.48809523809524
# Min 140
# Max 150
# Mean 145.45373134328358
# Min 141
# Max 150
# Mean 145.32937685459942
# Min 141
# Max 150
# Mean 145.27164179104477
# Min 141
# Max 149
# Mean 145.43413173652695
# Min 141
# Max 149
# Mean 145.52552552552552
# Min 141
# Max 149
# Mean 145.47761194029852
# Min 141
# Max 150
# Mean 143.35223880597016
# Min 139
# Max 148
# Mean 145.4658753709199
# Min 142
# Max 150
# Mean 145.35207100591717
# Min 141
# Max 149
# Mean 145.3746312684366
# Min 141
# Max 150
# Mean 145.39762611275964
# Min 141
# Max 150
# Mean 145.37869822485206
# Min 141
# Max 150
# Mean 145.5
# Min 141
# Max 150
# Mean 145.52522255192878
# Min 141
# Max 150
# Mean 145.52238805970148
# Min 141
# Max 150
# Mean 145.53592814371257
# Min 141
# Max 150
# Mean 145.4070796460177
# Min 141
# Max 150
# Mean 143.46428571428572
# Min 139
# Max 148
# Mean 145.39940828402368
# Min 141
# Max 150
# Mean 145.51632047477744
# Min 142
# Max 150
# Mean 145.46130952380952
# Min 141
# Max 150
# Mean 145.48203592814372
# Min 141
# Max 150
# Mean 145.41666666666666
# Min 141
# Max 150
# Mean 145.42857142857142
# Min 142
# Max 150
# Mean 145.55917159763314
# Min 141
# Max 150
# Mean 145.5
# Min 141
# Max 150
# Mean 145.44807121661722
# Min 142
# Max 150
# Mean 145.49262536873155
# Min 142
# Max 150
# Mean 143.44642857142858
# Min 139
# Max 147
# Mean 145.32544378698225
# Min 141
# Max 150
# Mean 145.31378299120234
# Min 141
# Max 150
# Mean 145.41666666666666
# Min 141
# Max 150
# Mean 145.4970238095238
# Min 141
# Max 150
# Mean 145.4540059347181
# Min 141
# Max 150
# Mean 145.5922619047619
# Min 141
# Max 150
# Mean 145.3550295857988
# Min 141
# Max 150
# Mean 144.40412979351032
# Min 141
# Max 148
# Mean 145.45103857566767
# Min 141
# Max 150
# Mean 145.3946587537092
# Min 142
# Max 150
# Mean 143.37014925373134
# Min 140
# Max 147
# Mean 145.40059347181008
# Min 141
# Max 149
# Mean 145.47619047619048
# Min 142
# Max 150
# Mean 145.4658753709199
# Min 142
# Max 149
# Mean 145.44179104477612
# Min 141
# Max 149
# Mean 145.48511904761904
# Min 142
# Max 149
# Mean 145.48816568047337
# Min 141
# Max 149
# Mean 145.41666666666666
# Min 141
# Max 150
# Mean 145.44837758112095
# Min 142
# Max 150
# Mean 145.36176470588236
# Min 141
# Max 150
# Mean 145.35693215339234
# Min 141
# Max 150
# Mean 144.38483965014578
# Min 140
# Max 149
# Mean 145.3462686567164
# Min 141
# Max 149
# Mean 145.46884272997033
# Min 141
# Max 149
# Mean 145.41246290801186
# Min 141
# Max 150
# Mean 145.44970414201183
# Min 141
# Max 150
# Mean 145.45697329376856
# Min 141
# Max 150
# Mean 145.50445103857567
# Min 141
# Max 150
# Mean 145.4807121661721
# Min 141
# Max 150
# Mean 145.40949554896142
# Min 141
# Max 149
# Mean 145.47058823529412
# Min 141
# Max 150
# Mean 145.42307692307693
# Min 141
# Max 149
# Mean 144.3918128654971
# Min 140
# Max 148
# Mean 145.53846153846155
# Min 142
# Max 150
# Mean 145.48214285714286
# Min 142
# Max 150
# Mean 145.44345238095238
# Min 141
# Max 149
# Mean 145.44736842105263
# Min 142
# Max 149
# Mean 145.43491124260356
# Min 142
# Max 149
# Mean 145.40532544378698
# Min 141
# Max 150
# Mean 145.49107142857142
# Min 142
# Max 150
# Mean 145.39583333333334
# Min 142
# Max 150
# Mean 145.39762611275964
# Min 141
# Max 149
# Mean 145.35398230088495
# Min 141
# Max 149
# Mean 144.41176470588235
# Min 141
# Max 149
# Mean 145.32937685459942
# Min 141
# Max 150
# Mean 145.45103857566767
# Min 142
# Max 150
# Mean 145.3323353293413
# Min 141
# Max 149
# Mean 145.3582089552239
# Min 141
# Max 149
# Mean 145.30383480825958
# Min 141
# Max 149
# Mean 145.36011904761904
# Min 141
# Max 150
# Mean 145.2920353982301
# Min 141
# Max 150
# Mean 145.32743362831857
# Min 141
# Max 149
# Mean 145.37869822485206
# Min 141
# Max 149
# Mean 145.49851632047478
# Min 141
# Max 150
# Mean 143.49112426035504
# Min 140
# Max 147
# Mean 143.4070796460177
# Min 139
# Max 147
# Mean 145.4319526627219
# Min 141
# Max 149
# Mean 145.39411764705883
# Min 141
# Max 149
# Mean 145.4867256637168
# Min 141
# Max 149
# Mean 145.33527696793004
# Min 142
# Max 149
# Mean 145.4457478005865
# Min 142
# Max 150
# Mean 145.40882352941176
# Min 141
# Max 150
# Mean 145.34421364985164
# Min 141
# Max 150
# Mean 145.35905044510386
# Min 141
# Max 150
# Mean 145.4154302670623
# Min 141
# Max 150
# Mean 145.40652818991097
# Min 141
# Max 150
# Mean 143.33333333333334
# Min 140
# Max 147
# Mean 145.3958944281525
# Min 141
# Max 150
# Mean 145.44510385756678
# Min 141
# Max 150
# Mean 145.38622754491018
# Min 142
# Max 149
# Mean 145.34029850746268
# Min 142
# Max 149
# Mean 145.32248520710058
# Min 142
# Max 149
# Mean 145.38988095238096
# Min 142
# Max 149
# Mean 145.46153846153845
# Min 142
# Max 149
# Mean 145.43323442136497
# Min 141
# Max 149
# Mean 145.33727810650888
# Min 141
# Max 150
# Mean 145.38938053097345
# Min 141
# Max 150
# Mean 143.32448377581122
# Min 140
# Max 147
# Mean 145.31750741839764
# Min 141
# Max 149
# Mean 145.38165680473372
# Min 141
# Max 150
# Mean 145.486646884273
# Min 141
# Max 149
# Mean 145.45238095238096
# Min 141
# Max 150
# Mean 145.4375
# Min 141
# Max 150
# Mean 145.47337278106508
# Min 142
# Max 150
# Mean 145.46153846153845
# Min 142
# Max 150
# Mean 145.36578171091446
# Min 142
# Max 149
# Mean 145.3905325443787
# Min 141
# Max 150
# Mean 145.25
# Min 142
# Max 149
# Mean 143.40828402366864
# Min 140
# Max 147
# Mean 145.2932551319648
# Min 142
# Max 149
# Mean 145.3830409356725
# Min 142
# Max 150
# Mean 145.46198830409358
# Min 141
# Max 150
# Mean 145.35
# Min 142
# Max 150
# Mean 145.4660766961652
# Min 142
# Max 150
# Mean 145.3598820058997
# Min 141
# Max 149
# Mean 145.25882352941176
# Min 141
# Max 150
# Mean 145.39002932551318
# Min 141
# Max 150
# Mean 145.32448377581122
# Min 141
# Max 150
# Mean 145.4023668639053
# Min 141
# Max 149
# Mean 144.46449704142012
# Min 141
# Max 149
# Mean 145.4526627218935
# Min 141
# Max 150
# Mean 145.3779761904762
# Min 142
# Max 150
# Mean 145.42729970326408
# Min 141
# Max 150
# Mean 145.41369047619048
# Min 141
# Max 150
# Mean 145.40356083086053
# Min 141
# Max 150
# Mean 145.53254437869822
# Min 141
# Max 150
# Mean 145.50147492625368
# Min 141
# Max 150
# Mean 145.35207100591717
# Min 141
# Max 150
# Mean 145.35693215339234
# Min 141
# Max 150
# Mean 145.41297935103245
# Min 142
# Max 150
# Mean 144.37388724035608
# Min 141
# Max 148
# Mean 145.39349112426035
# Min 142
# Max 150
# Mean 145.3049853372434
# Min 142
# Max 150
# Mean 145.35882352941175
# Min 142
# Max 150
# Mean 145.39644970414201
# Min 142
# Max 150
# Mean 145.50295857988166
# Min 141
# Max 149
# Mean 145.34411764705882
# Min 141
# Max 149
# Mean 145.4319526627219
# Min 141
# Max 149
# Mean 145.42603550295857
# Min 141
# Max 150
# Mean 145.4404761904762
# Min 141
# Max 150
# Mean 145.39583333333334
# Min 141
# Max 149
# Mean 144.42105263157896
# Min 140
# Max 149
# Mean 145.39221556886227
# Min 141
# Max 150
# Mean 145.42215568862275
# Min 142
# Max 150
# Mean 145.4358208955224
# Min 141
# Max 150
# Mean 145.37719298245614
# Min 142
# Max 150
# Mean 145.32258064516128
# Min 142
# Max 149
# Mean 145.3081395348837
# Min 142
# Max 149
# Mean 145.3108504398827
# Min 142
# Max 149
# Mean 145.42729970326408
# Min 142
# Max 150
# Mean 145.40949554896142
# Min 142
# Max 150
# Mean 145.45671641791046
# Min 142
# Max 150
# Mean 143.56379821958458
# Min 139
# Max 148
# Mean 145.46706586826346
# Min 142
# Max 149
# Mean 145.43154761904762
# Min 142
# Max 149
# Mean 145.4391691394659
# Min 142
# Max 150
# Mean 145.48816568047337
# Min 142
# Max 150
# Mean 145.46290801186944
# Min 141
# Max 150
# Mean 145.53709198813056
# Min 141
# Max 150
# Mean 145.42182890855457
# Min 141
# Max 150
# Mean 145.41666666666666
# Min 142
# Max 149
# Mean 145.47787610619469
# Min 142
# Max 150
# Mean 145.39880952380952
# Min 141
# Max 150
# Mean 143.45857988165682
# Min 139
# Max 147
# Mean 145.48809523809524
# Min 141
# Max 150
# Mean 145.3462686567164
# Min 141
# Max 149
# Mean 145.37278106508876
# Min 141
# Max 149
# Mean 145.32647058823528
# Min 141
# Max 149
# Mean 145.46017699115043
# Min 141
# Max 150
# Mean 145.39823008849558
# Min 141
# Max 150
# Mean 145.30994152046785
# Min 140
# Max 150
# Mean 145.31764705882352
# Min 141
# Max 150
# Mean 145.3846153846154
# Min 141
# Max 150
# Mean 145.29117647058823
# Min 142
# Max 149
# Mean 143.4306784660767
# Min 140
# Max 147
# Mean 145.3510324483776
# Min 141
# Max 149
# Mean 145.44378698224853
# Min 142
# Max 150
# Mean 145.42899408284023
# Min 142
# Max 149
# Mean 145.44510385756678
# Min 142
# Max 149
# Mean 145.31065088757396
# Min 142
# Max 149
# Mean 145.43880597014925
# Min 142
# Max 150
# Mean 145.44144144144144
# Min 141
# Max 150
# Mean 145.5
# Min 141
# Max 150
# Mean 145.47761194029852
# Min 141
# Max 149
# Mean 145.4089552238806
# Min 141
# Max 149
# Mean 143.41592920353983
# Min 139
# Max 147
# Mean 143.39940828402368
# Min 139
# Max 147
# Mean 145.45373134328358
# Min 141
# Max 149
# Mean 145.44837758112095
# Min 142
# Max 150
# Mean 145.3746312684366
# Min 141
# Max 150
# Mean 145.35190615835776
# Min 141
# Max 150
# Mean 145.27138643067846
# Min 142
# Max 150
# Mean 145.4017595307918
# Min 142
# Max 150
# Mean 145.3834808259587
# Min 141
# Max 150
# Mean 145.34218289085547
# Min 141
# Max 149
# Mean 145.34023668639054
# Min 141
# Max 150
# Mean 145.5044776119403
# Min 141
# Max 149
# Mean 144.52366863905326
# Min 140
# Max 149
# Mean 145.44011976047904
# Min 142
# Max 149
# Mean 145.35014836795253
# Min 141
# Max 149
# Mean 145.40117994100294
# Min 141
# Max 150
# Mean 145.5059171597633
# Min 141
# Max 150
# Mean 145.37910447761195
# Min 141
# Max 150
# Mean 145.42261904761904
# Min 142
# Max 149
# Mean 145.33432835820895
# Min 140
# Max 149
# Mean 145.47787610619469
# Min 141
# Max 149
# Mean 145.47462686567164
# Min 141
# Max 150
# Mean 145.40588235294118
# Min 142
# Max 150
# Mean 144.54277286135692
# Min 141
# Max 148
# Mean 145.42729970326408
# Min 141
# Max 150
# Mean 145.46567164179103
# Min 142
# Max 150
# Mean 145.47305389221557
# Min 142
# Max 149
# Mean 145.37048192771084
# Min 142
# Max 149
# Mean 145.4023668639053
# Min 142
# Max 149
# Mean 145.28402366863907
# Min 141
# Max 150
# Mean 145.3362831858407
# Min 141
# Max 149
# Mean 145.38938053097345
# Min 141
# Max 149
# Mean 145.47774480712167
# Min 142
# Max 149
# Mean 145.4404761904762
# Min 142
# Max 150
# Mean 144.4970238095238
# Min 140
# Max 148
# Mean 145.36904761904762
# Min 142
# Max 149
# Mean 145.48214285714286
# Min 142
# Max 149
# Mean 145.3834808259587
# Min 141
# Max 149
# Mean 145.38529411764705
# Min 141
# Max 149
# Mean 145.4017595307918
# Min 142
# Max 149
# Mean 145.4513274336283
# Min 142
# Max 150
# Mean 145.41935483870967
# Min 141
# Max 150
# Mean 145.39002932551318
# Min 141
# Max 150
# Mean 145.4047619047619
# Min 141
# Max 149
# Mean 145.41666666666666
# Min 141
# Max 150
# Mean 143.42011834319527
# Min 139
# Max 147
# Mean 145.48059701492537
# Min 142
# Max 150
# Mean 145.51775147928993
# Min 141
# Max 150
# Mean 145.3946587537092
# Min 142
# Max 149
# Mean 145.3834808259587
# Min 141
# Max 149
# Mean 145.47058823529412
# Min 141
# Max 150
# Mean 145.35
# Min 141
# Max 149
# Mean 145.32142857142858
# Min 141
# Max 149
# Mean 145.3550295857988
# Min 141
# Max 150
# Mean 145.39285714285714
# Min 141
# Max 150
# Mean 145.46268656716418
# Min 141
# Max 150
# Mean 143.4391691394659
# Min 139
# Max 147
# Mean 145.3963963963964
# Min 141
# Max 149
# Mean 145.44776119402985
# Min 141
# Max 150
# Mean 145.47774480712167
# Min 142
# Max 150
# Mean 145.43283582089552
# Min 142
# Max 150
# Mean 145.40356083086053
# Min 141
# Max 150
# Mean 145.40059347181008
# Min 141
# Max 150
# Mean 145.35014836795253
# Min 141
# Max 149
# Mean 145.4213649851632
# Min 141
# Max 150
# Mean 145.45238095238096
# Min 141
# Max 150
# Mean 145.54464285714286
# Min 142
# Max 150
# Mean 143.40059347181008
# Min 139
# Max 147
# Mean 145.46567164179103
# Min 142
# Max 149
# Mean 145.47761194029852
# Min 141
# Max 149
# Mean 145.4925816023739
# Min 141
# Max 150
# Mean 145.45671641791046
# Min 142
# Max 150
# Mean 145.4880239520958
# Min 142
# Max 150
# Mean 145.53869047619048
# Min 141
# Max 149
# Mean 145.47761194029852
# Min 142
# Max 149
# Mean 145.34023668639054
# Min 141
# Max 150
# Mean 145.37091988130564
# Min 142
# Max 149
# Mean 145.34319526627218
# Min 142
# Max 149
# Mean 143.51951951951952
# Min 139
# Max 147
# Mean 145.39285714285714
# Min 142
# Max 149
# Mean 145.35029940119762
# Min 141
# Max 150
# Mean 145.32937685459942
# Min 142
# Max 150
# Mean 145.4
# Min 142
# Max 150
# Mean 145.45535714285714
# Min 141
# Max 150
# Mean 145.32647058823528
# Min 141
# Max 149
# Mean 145.31858407079645
# Min 141
# Max 149
# Mean 145.42729970326408
# Min 142
# Max 150
# Mean 145.41369047619048
# Min 142
# Max 150
# Mean 145.5119760479042
# Min 142
# Max 150
# Mean 143.44179104477612
# Min 140
# Max 147
# Mean 145.4345238095238
# Min 141
# Max 150
# Mean 145.54925373134327
# Min 141
# Max 150
# Mean 145.35714285714286
# Min 142
# Max 149
# Mean 145.5
# Min 142
# Max 149
# Mean 145.3216374269006
# Min 142
# Max 149
# Mean 145.40828402366864
# Min 141
# Max 150
# Mean 145.3698224852071
# Min 142
# Max 149
# Mean 145.27565982404693
# Min 142
# Max 150
# Mean 145.3108504398827
# Min 141
# Max 150
# Mean 145.4112426035503
# Min 142
# Max 150
# Mean 144.4807121661721
# Min 140
# Max 148
# Mean 145.41666666666666
# Min 141
# Max 149
# Mean 145.44807121661722
# Min 141
# Max 149
# Mean 145.41616766467067
# Min 141
# Max 149
# Mean 145.39762611275964
# Min 141
# Max 149
# Mean 145.37573964497042
# Min 141
# Max 149
# Mean 145.41964285714286
# Min 141
# Max 149
# Mean 145.43880597014925
# Min 141
# Max 149
# Mean 145.54626865671642
# Min 142
# Max 149
# Mean 145.50149253731342
# Min 141
# Max 150
# Mean 145.4467455621302
# Min 142
# Max 149
# Mean 143.45562130177515
# Min 139
# Max 148
# Mean 144.4213649851632
# Min 140
# Max 149
# Mean 145.3887240356083
# Min 142
# Max 150
# Mean 145.4047619047619
# Min 141
# Max 150
# Mean 145.42772861356931
# Min 142
# Max 149
# Mean 145.41055718475073
# Min 142
# Max 149
# Mean 145.35311572700297
# Min 142
# Max 149
# Mean 145.42857142857142
# Min 141
# Max 150
# Mean 145.459940652819
# Min 141
# Max 150
# Mean 145.34017595307918
# Min 141
# Max 150
# Mean 145.37278106508876
# Min 141
# Max 150
# Mean 145.43491124260356
# Min 142
# Max 150
# Mean 143.4268656716418
# Min 139
# Max 147
# Mean 145.50149253731342
# Min 142
# Max 149
# Mean 145.4970238095238
# Min 142
# Max 149
# Mean 145.5654761904762
# Min 142
# Max 149
# Mean 145.51632047477744
# Min 142
# Max 149
# Mean 145.53709198813056
# Min 142
# Max 150
# Mean 145.35588235294117
# Min 141
# Max 150
# Mean 145.34718100890208
# Min 141
# Max 149
# Mean 145.31764705882352
# Min 141
# Max 149
# Mean 145.32640949554897
# Min 141
# Max 149
# Mean 145.41002949852506
# Min 142
# Max 149
# Mean 143.4391691394659
# Min 139
# Max 147
# Mean 145.35798816568047
# Min 142
# Max 150
# Mean 145.38690476190476
# Min 142
# Max 150
# Mean 145.48955223880597
# Min 142
# Max 149
# Mean 145.31845238095238
# Min 141
# Max 149
# Mean 145.45238095238096
# Min 141
# Max 149
# Mean 145.33823529411765
# Min 141
# Max 149
# Mean 145.40882352941176
# Min 142
# Max 149
# Mean 145.44510385756678
# Min 141
# Max 149
# Mean 145.3510324483776
# Min 141
# Max 150
# Mean 145.31360946745562
# Min 141
# Max 149
# Mean 143.38922155688624
# Min 140
# Max 147
# Mean 145.35329341317365
# Min 141
# Max 149
# Mean 145.32640949554897
# Min 141
# Max 149
# Mean 145.3846153846154
# Min 142
# Max 149
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-910432ae4eaf> in <module>
#       6     img = cv2.imread("{}/{}".format(folder_path, file), 0)
#       7     _, nlm, _, edge = image_processing(img)
# ----> 8     edge_points = get_edge_points(edge)
#       9
#      10
#
# <ipython-input-1-26504a113168> in get_edge_points(edge_img)
#       8
#       9 def get_edge_points(edge_img):
# ---> 10     edge_points = [[j,i] for i, r in enumerate(edge_img) for j, c in enumerate(r) if c == 255]
#      11
#      12     return edge_points
#
# <ipython-input-1-26504a113168> in <listcomp>(.0)
#       8
#       9 def get_edge_points(edge_img):
# ---> 10     edge_points = [[j,i] for i, r in enumerate(edge_img) for j, c in enumerate(r) if c == 255]
#      11
#      12     return edge_points
#
# KeyboardInterrupt:

# %% [markdown]
# ## 實際測試

# %%
os.chdir("/home/mj/HardDisk/Github/NTU/ARCS/img/X-Ray/New/Case_4")

files = os.listdir()
files.sort()
files = np.asarray(files)
batches = np.split(files, 297)

predictions = []
for batch in batches:
    images = [cv2.imread(img,0) for img in batch]
    roi_loc = Get_ROI(images[0])
    predicted = Analize_Multi_Frames(roi_loc, images)
    predictions.append(predicted)
    print("{}, {}".format(predicted[0], predicted[1]))
# Out:
# 86.33796712905507, 72.67534812564438
# 86.46597107039965, 72.74301307545917
# 86.41055526761397, 72.71868398529531
# 86.30283428584302, 72.59324967493225
# 86.4402933348428, 72.76240266032354
# 86.46387177622442, 72.68137996471114
# 86.36012327423532, 72.78733131827344
# 86.29802755291234, 72.84693353885541
# 86.43430033236791, 72.96455115401321
# 86.39962077678447, 72.8153764084023
# 86.39272191731509, 72.87085947044669
# 86.31160624229372, 72.77810643049244
# 86.33494455845187, 72.87236300477224
# 86.28798262180354, 72.92795420357416
# 86.3706065969928, 72.72580027485205
# 86.2554327504046, 72.7908460978399
# 86.40867406944295, 72.74501856039537
# 86.41230636154705, 72.79199948554444
# 86.37558490144974, 72.83018816271775
# 86.42408816951868, 72.7198041566906
# 86.38863611655145, 72.78305308577092
# 86.36928979010275, 72.70001727174837
# 86.39322284405053, 72.7606644206661
# 86.45762856584906, 72.81138253439264
# 86.33761447613334, 72.8106272666329
# 86.37698451782884, 72.7535940263054
# 86.36209847407562, 72.70734118119789
# 86.33675775195125, 72.8613183043426
# 86.44181231817757, 72.78598161863286
# 86.38344095556144, 72.83771284859839
# 86.32009175580305, 72.85797141232058
# 86.44961834009553, 72.71599924069082
# 86.3967663792886, 72.86377297730522
# 86.45216757431888, 72.89601302131935
# 86.3179068850028, 72.87693912271777
# 86.40020033641215, 72.78146617049757
# 86.31163551766062, 72.82085716073793
# 86.40293017770138, 72.7322726112586
# 86.4153153346273, 72.78662041797406
# 86.43540296524657, 72.66456713776594
# 86.36530641403328, 72.68790317929147
# 86.38603570317159, 72.7883383158766
# 86.28703988618334, 72.84355219875386
# 86.46957782928331, 72.84430660664279
# 86.4144312135877, 72.79654302278703
# 86.34301097055454, 72.7642472014428
# 86.35952766515386, 72.81516825892311
# 86.31787422912899, 72.90124738301097
# 86.39036693916938, 72.82242083173674
# 86.4225156752199, 72.8051603479581
# 86.3887350154813, 72.84738381712518
# 86.35245859780474, 72.83514811401443
# 86.38028692402398, 72.89337549312867
# 86.35235975372993, 72.82260798390436
# 86.41267059728925, 72.78329480328765
# 86.35965729076341, 72.7669448813134
# 86.37892037703281, 72.850846002579
# 86.39029175749374, 72.7686212730726
# 86.4142833073757, 72.80266437125081
# 86.40036464555197, 72.77615322211344
# 86.38390735674705, 72.88143717318374
# 86.39581244126433, 72.86114921610982
# 86.36601120182874, 72.84644064144268
# 86.37403744096898, 72.80994080378804
# 86.38096490475687, 72.89416777866717
# 86.3550822281027, 72.80654547167856
# 86.3643521069641, 72.82038112689088
# 86.36430702599526, 72.81710583696113
# 86.411620418871, 72.84992511130999
# 86.30147929314431, 72.78240663477587
# 86.30051793225834, 72.84929127705506
# 86.34046523612159, 72.86617815896334
# 86.32677685901733, 72.77145402064129
# 86.28755874677427, 72.83683939447965
# 86.31633090453411, 72.83226339377549
# 86.37629937086011, 72.73825956292148
# 86.3322269848199, 72.7887717308835
# 86.29846765387694, 72.87140564661027
# 86.33890610040649, 72.76707999835799
# 86.31689507337376, 72.88333832356088
# 86.4300047459194, 72.86656480222118
# 86.39765385383512, 72.7363726829129
# 86.32975828983498, 72.8699673966717
# 86.40857022663135, 72.83402988674668
# 86.34618308271537, 72.82015239659327
# 86.3523408002074, 72.82643673204306
# 86.31283411083965, 72.82684879396547
# 86.30668560138562, 72.79395270608046
# 86.25904387885492, 72.82476786297802
# 86.39481360313518, 72.76803127980858
# 86.35233489582981, 72.79908896778838
# 86.36391698144081, 72.8465456936267
# 86.31542029916187, 72.89261087170343
# 86.3650850479103, 72.82006932622718
# 86.34524193390195, 72.91468829040892
# 86.34128888024163, 72.85086871940169
# 86.39395440697443, 72.98402282906174
# 86.29523130885632, 72.81756464504618
# 86.33642760183841, 72.83347294344387
# 86.32933733139255, 72.81652693470268
# 86.35415028189857, 72.82445373711386
# 86.33868874694505, 72.84419717645409
# 86.38699676398008, 72.88202026667403
# 86.36271779557458, 72.80472755849024
# 86.35603993680057, 72.80069880896747
# 86.42912648561338, 72.76695084405475
# 86.3640828231679, 72.79377573522845
# 86.33707320219989, 72.85505996986188
# 86.31136265298674, 72.82446925079697
# 86.35458000240996, 72.80293800652805
# 86.36012754474845, 72.82954780856888
# 86.37848411800334, 72.86717858875076
# 86.36099693248718, 72.84299597115644
# 86.46335599084988, 72.90930765938154
# 86.38690832882686, 72.89899567050183
# 86.41599852979627, 72.81249488126487
# 86.40797421770424, 72.84061241106181
# 86.35893563165963, 72.88995328803654
# 86.39216050132417, 72.99398673056815
# 86.3112077134935, 72.88832182425296
# 86.34787754863285, 72.75118043345606
# 86.34032174742426, 72.76184409687602
# 86.47865147777759, 72.7290184315712
# 86.31997889700199, 72.86680402258025
# 86.38501096132546, 72.7799807404553
# 86.31554798976137, 72.7894636210546
# 86.41166059839543, 72.7511747227991
# 86.43844252900034, 72.82872210245284
# 86.3631656144798, 72.89991271357343
# 86.44150537773137, 72.89396346285835
# 86.29958085970952, 72.81198123074682
# 86.39825389407305, 72.90064784016073
# 86.34854405939205, 72.90206757697692
# 86.40172272337543, 72.99664049418024
# 86.40653443742283, 72.66093506731684
# 86.5290082688094, 72.8782137717745
# 86.42229766214979, 72.82834208671729
# 86.34021621271879, 72.88898068789067
# 86.3508312735408, 72.79037269332215
# 86.3918182857179, 72.83367053700263
# 86.47848799633059, 72.84448774045673
# 86.3629561180764, 72.85211193165222
# 86.45532981710502, 72.78657023015958
# 86.42526018526355, 72.83902240038378
# 86.3786196837818, 72.90887491530795
# 86.33837339702933, 72.84905479410571
# 86.38462063840731, 72.9244107010121
# 86.35353847236537, 72.80213662216553
# 86.44539034903863, 72.84902568162673
# 86.49997934991487, 72.83274874497036
# 86.34929535562235, 72.83694301620466
# 86.37097501943758, 72.90600144795503
# 86.24595043643492, 72.77686020818875
# 86.36461180926725, 72.77265430498554
# 86.45364336263546, 72.80826189002653
# 86.39892927830944, 72.79253717196781
# 86.45800125835774, 72.80968008833023
# 86.36671302035403, 72.90767102777335
# 86.40288300803039, 72.81020072172012
# 86.31481903203229, 72.81706499821229
# 86.35705918049769, 72.82864233417038
# 86.32838789833878, 72.76486185546531
# 86.44452324193588, 72.8770828333094
# 86.38018856770009, 72.94157037141538
# 86.3786680738454, 72.9201190343644
# 86.34996122419521, 72.90559876329937
# 86.47068374310368, 72.92511924673146
# 86.36527773817039, 72.97626619475537
# 86.4757972558022, 72.99007633666427
# 86.42794676296198, 72.95867380074411
# 86.42755206433264, 72.86026352701722
# 86.41641675818349, 72.97763121179574
# 86.39808456107122, 72.93978419672406
# 86.4482280358734, 72.92474773591638
# 86.3891513997197, 72.92393039998774
# 86.31744528250896, 72.92640338030914
# 86.47318142882847, 72.88882652522102
# 86.38760800361197, 72.85170906086026
# 86.3848940738612, 72.89043004912705
# 86.35922223667436, 72.76894770336096
# 86.35502877317802, 72.92156640817578
# 86.39081156770553, 72.85939473504939
# 86.36721547916716, 72.91956814720825
# 86.39055783890527, 72.80365233689363
# 86.46734350898188, 72.90105132815626
# 86.4236241693659, 72.97842366714366
# 86.32266079994895, 72.91651871962131
# 86.44298727186346, 72.93549907531019
# 86.39350667267406, 72.84628611740361
# 86.34468184310094, 72.85801446215382
# 86.38264017080348, 72.75999089065601
# 86.3892116000744, 72.79750554581517
# 86.39890207963899, 72.85326967655111
# 86.46418995404048, 72.81194320534567
# 86.37693279223491, 72.91504142378012
# 86.40579547232282, 72.8236123259475
# 86.28747968165277, 72.9492133885415
# 86.32392916731945, 72.89820829034113
# 86.36857917969078, 72.85033614765656
# 86.39385619280053, 72.95200630813227
# 86.3838960769405, 72.80930560492055
# 86.31646628396345, 72.89043657326812
# 86.45492580855046, 72.94090517635782
# 86.39173063056275, 72.73435794796261
# 86.42781350708813, 72.90284810013455
# 86.4050241799799, 72.80675714649242
# 86.41055815427583, 72.91944994481028
# 86.39422127049048, 72.92246697767186
# 86.36124280790216, 72.91739766502454
# 86.3454143155885, 72.83777301694238
# 86.37871802795974, 72.88161763101076
# 86.31132529774064, 72.90365261978903
# 86.3175533602905, 72.84990393967942
# 86.34828836098126, 72.8814230729757
# 86.32508254807291, 72.80173951636479
# 86.38250415007644, 72.92944909826214
# 86.37032427351267, 72.8453812039442
# 86.38733249828366, 72.85432290741127
# 86.48766486152414, 72.87691810243729
# 86.4336755777492, 72.66584480124077
# 86.33953622569783, 72.68937834291341
# 86.3823010577061, 72.68589234258897
# 86.32608023615666, 72.75166281193786
# 86.37115223667583, 72.78986130790594
# 86.26337096292887, 72.66104967063467
# 86.35214283423917, 72.74792670108233
# 86.26115641603263, 72.69430695901731
# 86.31340248786753, 72.75809808269226
# 86.32250724938778, 72.69242620280227
# 86.37822433403667, 72.71653521792638
# 86.30824479103617, 72.73666050290672
# 86.37412415978028, 72.59579724255053
# 86.33774028947549, 72.73123278587774
# 86.38496996396601, 72.6888826454107
# 86.40866798366952, 72.90928080120753
# 86.40032360764353, 72.78249837955023
# 86.31097260395896, 72.81520796426962
# 86.41058954529754, 72.70296307957318
# 86.30848349961971, 72.74589934977831
# 86.33798334215001, 72.81231866497328
# 86.41268988381776, 72.7537842928919
# 86.421381333999, 72.74895884532077
# 86.39440456463339, 72.70298288648851
# 86.3839609163263, 72.71429630120602
# 86.30618826698283, 72.79822173695544
# 86.48001745962657, 72.68676840587426
# 86.40629730350884, 72.69078354849415
# 86.31219999767802, 72.78516246382469
# 86.33795997394395, 72.76847846082694
# 86.42035247314081, 72.70010477514381
# 86.3093085703616, 72.66038382145393
# 86.38068686902193, 72.70186173582873
# 86.37462582677824, 72.82205464728797
# 86.3580449502208, 72.74872360320953
# 86.42343223840726, 72.69849353127626
# 86.43973125123819, 72.66553717370493
# 86.36702604754785, 72.729435609902
# 86.30298704955976, 72.89482577716038
# 86.36563988375761, 72.75254630908796
# 86.2939282427154, 72.68948527342778
# 86.33599659129955, 72.84235790732603
# 86.39394304704956, 72.6972043619198
# 86.32914397437463, 72.71297481860992
# 86.34340513561646, 72.65861011579872
# 86.28787519794365, 72.73380977847128
# 86.40129921857789, 72.7172897812122
# 86.41526295190151, 72.75662916772981
# 86.37521963560656, 72.69917090894633
# 86.3492506769947, 72.71200370478388
# 86.29737837107638, 72.75734185658604
# 86.3543753739524, 72.76463217253712
# 86.39835812581211, 72.79440509553169
# 86.39084948835719, 72.72922165105356
# 86.34186898018379, 72.69246868178959
# 86.40540584492585, 72.81064205536772
# 86.33543523681031, 72.86260880545066
# 86.34067111189346, 72.7480823052579
# 86.35004639977805, 72.82155248745138
# 86.30488637112524, 72.67064514970406
# 86.35824511262655, 72.69288937492333
# 86.31183409914976, 72.7272634582653
# 86.32680019506896, 72.7716439649577
# 86.42542790656177, 72.73407545905417
# 86.41420767251941, 72.7371837514012
# 86.37254526092782, 72.72862907585153
# 86.36188571415519, 72.69009390893814
# 86.36679529456286, 72.74888474689848
# 86.39412636343411, 72.70643950442818
# 86.44288912435334, 72.64783668804526
# 86.42505446807596, 72.77311952495214
# 86.38893302884844, 72.89126970153379
# 86.32827236836249, 72.71313345256203
# 86.39887276967235, 72.83743309595388
# 86.31379070179335, 72.73224955672259
# 86.36760673522221, 72.77114274532524
# 86.39146299029875, 72.68140608845093
# 86.3424242544783, 72.73970882461074

# %%
show_resoult(predictions)
# Out:
# -----------------------------------------------------
# Statistics:
# Mean Centroid: (86.37343, 72.81116)
# Variance     : (0.00238, 0.00625)
# Max Length   : 0.28306, 0.40339 (pixels)

# %% [markdown]
# ## 算機率

# %%
from scipy.special import comb

def Count_Probability(num_tal, num_sel, prob):
    x = prob
    y = 1 - x
    
    result = 0
    for i in range(num_sel, num_tal+1):
        num_x = i 
        num_y = num_tal - i
        result = result + comb(num_tal, i) * x**num_x * y**num_y
    
    return result

Count_Probability(20,10,0.65)
# Out:
# 0.9468333856370541
